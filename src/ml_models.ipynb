# %% [markdown]
# <a href="https://colab.research.google.com/github/vunnampragathi/projects/blob/main/src/ml_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
COL_LIST = ['State','Date Local','NO2 AQI','NO2 Mean','O3 AQI','O3 Mean','CO AQI','CO Mean','SO2 AQI','SO2 Mean']

# %%
data = pd.read_csv("/content/uspollution_pollution_us_2000_2016.csv",usecols =COL_LIST )

# %%
data
# Out:
#                State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  \
# 0            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 1            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 2            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 3            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 4            Arizona  2000-01-02  22.958333     34.0  0.013375    27.0
# ...              ...         ...        ...      ...       ...     ...
# 347007  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347008  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347009  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347010  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347011           NaN         NaN        NaN      NaN       NaN     NaN
#
#         SO2 Mean  SO2 AQI   CO Mean  CO AQI
# 0       3.000000     13.0  1.145833     NaN
# 1       3.000000     13.0  0.878947    25.0
# 2       2.975000      NaN  1.145833     NaN
# 3       2.975000      NaN  0.878947    25.0
# 4       1.958333      4.0  0.850000     NaN
# ...          ...      ...       ...     ...
# 347007  4.541667     16.0  0.304167     NaN
# 347008  4.541667     16.0  0.270833     5.0
# 347009  4.500000      NaN  0.304167     NaN
# 347010  4.500000      NaN  0.270833     5.0
# 347011       NaN      NaN       NaN     NaN
#
# [347012 rows x 10 columns]

# %%
df=data.fillna(method='ffill')
df
# Out:
#                State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  \
# 0            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 1            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 2            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 3            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 4            Arizona  2000-01-02  22.958333     34.0  0.013375    27.0
# ...              ...         ...        ...      ...       ...     ...
# 347007  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347008  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347009  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347010  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347011  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
#
#         SO2 Mean  SO2 AQI   CO Mean  CO AQI
# 0       3.000000     13.0  1.145833     NaN
# 1       3.000000     13.0  0.878947    25.0
# 2       2.975000     13.0  1.145833    25.0
# 3       2.975000     13.0  0.878947    25.0
# 4       1.958333      4.0  0.850000    25.0
# ...          ...      ...       ...     ...
# 347007  4.541667     16.0  0.304167     3.0
# 347008  4.541667     16.0  0.270833     5.0
# 347009  4.500000     16.0  0.304167     5.0
# 347010  4.500000     16.0  0.270833     5.0
# 347011  4.500000     16.0  0.270833     5.0
#
# [347012 rows x 10 columns]

# %%
df=df.fillna(method='bfill')

# %%
df
# Out:
#                State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  \
# 0            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 1            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 2            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 3            Arizona  2000-01-01  19.041667     46.0  0.022500    34.0
# 4            Arizona  2000-01-02  22.958333     34.0  0.013375    27.0
# ...              ...         ...        ...      ...       ...     ...
# 347007  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347008  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347009  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347010  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
# 347011  Pennsylvania  2003-06-29  13.125000     43.0  0.042250    74.0
#
#         SO2 Mean  SO2 AQI   CO Mean  CO AQI
# 0       3.000000     13.0  1.145833    25.0
# 1       3.000000     13.0  0.878947    25.0
# 2       2.975000     13.0  1.145833    25.0
# 3       2.975000     13.0  0.878947    25.0
# 4       1.958333      4.0  0.850000    25.0
# ...          ...      ...       ...     ...
# 347007  4.541667     16.0  0.304167     3.0
# 347008  4.541667     16.0  0.270833     5.0
# 347009  4.500000     16.0  0.304167     5.0
# 347010  4.500000     16.0  0.270833     5.0
# 347011  4.500000     16.0  0.270833     5.0
#
# [347012 rows x 10 columns]

# %%
df1=df.loc[df['State'] == "California"]

# %%
df1
# Out:
#              State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  \
# 3516    California  2000-01-01  14.782609     25.0  0.015542    25.0
# 3517    California  2000-01-01  14.782609     25.0  0.015542    25.0
# 3518    California  2000-01-01  14.782609     25.0  0.015542    25.0
# 3519    California  2000-01-01  14.782609     25.0  0.015542    25.0
# 3520    California  2000-01-02  16.043478     28.0  0.015292    27.0
# ...            ...         ...        ...      ...       ...     ...
# 314690  California  2003-12-30   7.681818     25.0  0.030053    29.0
# 314691  California  2003-12-31  13.857143     29.0  0.017833    24.0
# 314692  California  2003-12-31  13.857143     29.0  0.017833    24.0
# 314693  California  2003-12-31  13.857143     29.0  0.017833    24.0
# 314694  California  2003-12-31  13.857143     29.0  0.017833    24.0
#
#         SO2 Mean  SO2 AQI   CO Mean  CO AQI
# 3516    0.636364      3.0  0.556522    22.0
# 3517    0.636364      3.0  0.572222     9.0
# 3518    0.600000      3.0  0.556522     9.0
# 3519    0.600000      3.0  0.572222     9.0
# 3520    1.000000      3.0  0.578261     9.0
# ...          ...      ...       ...     ...
# 314690  0.000000      0.0  0.379167     6.0
# 314691  0.047619      1.0  0.633333     6.0
# 314692  0.047619      1.0  0.600000    10.0
# 314693  0.042857      1.0  0.633333    10.0
# 314694  0.042857      1.0  0.600000    10.0
#
# [147801 rows x 10 columns]

# %% [markdown]
# ## Statistical Test for detecting stationarity:ADF test

# %%
from statsmodels.tsa.stattools import adfuller
stat_test = adfuller(df1['CO AQI'])
print('The test statistic for CO AQI is {} and p-value is {}'.format(stat_test[0], stat_test[1]))
# Out:
# The test statistic for CO AQI is -14.910603073690835 and p-value is 1.460439855191098e-27

# %% [markdown]
# it is observed that p value of CO AQI is approximately eqaul to 0. it is quite obvious that the time series becomes stationary.

# %% [markdown]
# ## ACF plot and PACF plot

# %%
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
sm.graphics.tsa.plot_acf(df1['CO AQI'], lags=35);

# %%
sm.graphics.tsa.plot_pacf(df1['CO AQI'], lags=35);
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
train_len = int(len(df1['CO AQI']) * 0.8)
df_train = df1['CO AQI'][:train_len]
df_test = df1['CO AQI'][train_len:]
start = len(df_train)
end = len(df_train) + len(df_test) - 1

# %%
ma_model = ARIMA(df_train, order=(0, 0, 5))
ma_result = ma_model.fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
 ma_pred = ma_result.predict(start, end)
ma_pred.index = df_test.index
plt.plot(df_train.index, df_train, label='Train')
plt.plot(df_test.index, df_test, label='Test')
plt.plot(ma_pred.index , ma_pred, label='predictions')
plt.legend()
plt.xlabel('Date')
plt.show()

mae_ma = mean_absolute_error(df_test, ma_pred)
mse_ma = mean_squared_error(df_test, ma_pred)
rmse_ma = np.sqrt(mean_squared_error(df_test, ma_pred))
ma_perf = {'mae_ma': mae_ma,
             'mse_ma':mse_ma,
             'rmse_ma':rmse_ma}
ma_perf = pd.DataFrame([ma_perf])
    
print(ma_perf)
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#      mae_ma     mse_ma   rmse_ma
# 0  6.387879  77.957364  8.829347

# %% [markdown]
# https://www.justintodata.com/arima-models-in-python-time-series-prediction/
