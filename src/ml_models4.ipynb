# %% [markdown]
# <a href="https://colab.research.google.com/github/vunnampragathi/projects/blob/main/src/ml_models4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score 
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
COL_LIST = ['State','Date Local','NO2 AQI','NO2 Mean','O3 AQI','O3 Mean','CO AQI','CO Mean','SO2 AQI','SO2 Mean']

# %%
data = pd.read_csv("/content/uspollution_pollution_us_2000_2016.csv",usecols =COL_LIST )

# %%
data
# Out:
#            State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  SO2 Mean  \
# 0        Arizona  2000-01-01  19.041667       46  0.022500      34  3.000000
# 1        Arizona  2000-01-01  19.041667       46  0.022500      34  3.000000
# 2        Arizona  2000-01-01  19.041667       46  0.022500      34  2.975000
# 3        Arizona  2000-01-01  19.041667       46  0.022500      34  2.975000
# 4        Arizona  2000-01-02  22.958333       34  0.013375      27  1.958333
# ...          ...         ...        ...      ...       ...     ...       ...
# 1746656  Wyoming  2016-03-30   1.083333        1  0.043917      44  0.000000
# 1746657  Wyoming  2016-03-31   0.939130        1  0.045263      44 -0.022727
# 1746658  Wyoming  2016-03-31   0.939130        1  0.045263      44 -0.022727
# 1746659  Wyoming  2016-03-31   0.939130        1  0.045263      44  0.000000
# 1746660  Wyoming  2016-03-31   0.939130        1  0.045263      44  0.000000
#
#          SO2 AQI   CO Mean  CO AQI
# 0           13.0  1.145833     NaN
# 1           13.0  0.878947    25.0
# 2            NaN  1.145833     NaN
# 3            NaN  0.878947    25.0
# 4            4.0  0.850000     NaN
# ...          ...       ...     ...
# 1746656      NaN  0.091667     1.0
# 1746657      0.0  0.067714     NaN
# 1746658      0.0  0.100000     1.0
# 1746659      NaN  0.067714     NaN
# 1746660      NaN  0.100000     1.0
#
# [1746661 rows x 10 columns]

# %%
df=data.fillna(method='ffill')
df
# Out:
#            State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  SO2 Mean  \
# 0        Arizona  2000-01-01  19.041667       46  0.022500      34  3.000000
# 1        Arizona  2000-01-01  19.041667       46  0.022500      34  3.000000
# 2        Arizona  2000-01-01  19.041667       46  0.022500      34  2.975000
# 3        Arizona  2000-01-01  19.041667       46  0.022500      34  2.975000
# 4        Arizona  2000-01-02  22.958333       34  0.013375      27  1.958333
# ...          ...         ...        ...      ...       ...     ...       ...
# 1746656  Wyoming  2016-03-30   1.083333        1  0.043917      44  0.000000
# 1746657  Wyoming  2016-03-31   0.939130        1  0.045263      44 -0.022727
# 1746658  Wyoming  2016-03-31   0.939130        1  0.045263      44 -0.022727
# 1746659  Wyoming  2016-03-31   0.939130        1  0.045263      44  0.000000
# 1746660  Wyoming  2016-03-31   0.939130        1  0.045263      44  0.000000
#
#          SO2 AQI   CO Mean  CO AQI
# 0           13.0  1.145833     NaN
# 1           13.0  0.878947    25.0
# 2           13.0  1.145833    25.0
# 3           13.0  0.878947    25.0
# 4            4.0  0.850000    25.0
# ...          ...       ...     ...
# 1746656      0.0  0.091667     1.0
# 1746657      0.0  0.067714     1.0
# 1746658      0.0  0.100000     1.0
# 1746659      0.0  0.067714     1.0
# 1746660      0.0  0.100000     1.0
#
# [1746661 rows x 10 columns]

# %%
df=df.fillna(method='bfill')

# %%
df
# Out:
#            State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  SO2 Mean  \
# 0        Arizona  2000-01-01  19.041667       46  0.022500      34  3.000000
# 1        Arizona  2000-01-01  19.041667       46  0.022500      34  3.000000
# 2        Arizona  2000-01-01  19.041667       46  0.022500      34  2.975000
# 3        Arizona  2000-01-01  19.041667       46  0.022500      34  2.975000
# 4        Arizona  2000-01-02  22.958333       34  0.013375      27  1.958333
# ...          ...         ...        ...      ...       ...     ...       ...
# 1746656  Wyoming  2016-03-30   1.083333        1  0.043917      44  0.000000
# 1746657  Wyoming  2016-03-31   0.939130        1  0.045263      44 -0.022727
# 1746658  Wyoming  2016-03-31   0.939130        1  0.045263      44 -0.022727
# 1746659  Wyoming  2016-03-31   0.939130        1  0.045263      44  0.000000
# 1746660  Wyoming  2016-03-31   0.939130        1  0.045263      44  0.000000
#
#          SO2 AQI   CO Mean  CO AQI
# 0           13.0  1.145833    25.0
# 1           13.0  0.878947    25.0
# 2           13.0  1.145833    25.0
# 3           13.0  0.878947    25.0
# 4            4.0  0.850000    25.0
# ...          ...       ...     ...
# 1746656      0.0  0.091667     1.0
# 1746657      0.0  0.067714     1.0
# 1746658      0.0  0.100000     1.0
# 1746659      0.0  0.067714     1.0
# 1746660      0.0  0.100000     1.0
#
# [1746661 rows x 10 columns]

# %%
df1=df.loc[df['State'] == "California"]

# %%
df1
# Out:
#               State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  \
# 3516     California  2000-01-01  14.782609       25  0.015542      25
# 3517     California  2000-01-01  14.782609       25  0.015542      25
# 3518     California  2000-01-01  14.782609       25  0.015542      25
# 3519     California  2000-01-01  14.782609       25  0.015542      25
# 3520     California  2000-01-02  16.043478       28  0.015292      27
# ...             ...         ...        ...      ...       ...     ...
# 1729192  California  2016-04-29   3.643478        8  0.032417      35
# 1729193  California  2016-04-30   4.160870       12  0.038053      38
# 1729194  California  2016-04-30   4.160870       12  0.038053      38
# 1729195  California  2016-04-30   4.160870       12  0.038053      38
# 1729196  California  2016-04-30   4.160870       12  0.038053      38
#
#          SO2 Mean  SO2 AQI   CO Mean  CO AQI
# 3516     0.636364      3.0  0.556522    22.0
# 3517     0.636364      3.0  0.572222     9.0
# 3518     0.600000      3.0  0.556522     9.0
# 3519     0.600000      3.0  0.572222     9.0
# 3520     1.000000      3.0  0.578261     9.0
# ...           ...      ...       ...     ...
# 1729192  0.457143      0.0  0.262500     3.0
# 1729193  0.468182      0.0  0.247826     3.0
# 1729194  0.468182      0.0  0.245833     3.0
# 1729195  0.442857      0.0  0.247826     3.0
# 1729196  0.442857      0.0  0.245833     3.0
#
# [576142 rows x 10 columns]

# %%
df1.drop_duplicates(subset=['Date Local'], inplace=True)
df1
# Out:
#               State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  \
# 3516     California  2000-01-01  14.782609       25  0.015542      25
# 3520     California  2000-01-02  16.043478       28  0.015292      27
# 3524     California  2000-01-03  25.521739       38  0.005625      12
# 3528     California  2000-01-04  26.041667       42  0.006083       9
# 3532     California  2000-01-05  23.772727       36  0.010500      19
# ...             ...         ...        ...      ...       ...     ...
# 1724161  California  2016-04-30   8.434783       23  0.032158      36
# 1724477  California  2016-03-19   2.982609        3  0.027708      31
# 1724481  California  2016-03-20   2.269565        7  0.026625      30
# 1724485  California  2016-03-21   3.552174        6  0.034208      39
# 1724489  California  2016-03-22   4.226087       18  0.026292      35
#
#          SO2 Mean  SO2 AQI   CO Mean  CO AQI
# 3516     0.636364      3.0  0.556522    22.0
# 3520     1.000000      3.0  0.578261     9.0
# 3524     2.454545      6.0  1.313043     9.0
# 3528     1.541667      6.0  1.187500    22.0
# 3532     1.681818      6.0  1.136364    23.0
# ...           ...      ...       ...     ...
# 1724161  0.900000      1.0  0.339130     5.0
# 1724477  0.372727      0.0  0.400000     6.0
# 1724481  0.359091      0.0  0.391304     5.0
# 1724485  0.390909      0.0  0.395652     5.0
# 1724489  0.636364      1.0  0.369565     5.0
#
# [5965 rows x 10 columns]

# %% [markdown]
# The pollutant with the highest AQI value determines the overall AQI for that hour.
#
# ref:https://www.pca.state.mn.us/air-water-land-climate/understanding-the-air-quality-index-aqi#:~:text=The%20AQI%20is%20calculated%20by,National%20Ambient%20Air%20Quality%20Standards.

# %%
df1["AQI"] = df1.max(axis=1)
df1
# Out:
#               State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  \
# 3516     California  2000-01-01  14.782609       25  0.015542      25
# 3520     California  2000-01-02  16.043478       28  0.015292      27
# 3524     California  2000-01-03  25.521739       38  0.005625      12
# 3528     California  2000-01-04  26.041667       42  0.006083       9
# 3532     California  2000-01-05  23.772727       36  0.010500      19
# ...             ...         ...        ...      ...       ...     ...
# 1724161  California  2016-04-30   8.434783       23  0.032158      36
# 1724477  California  2016-03-19   2.982609        3  0.027708      31
# 1724481  California  2016-03-20   2.269565        7  0.026625      30
# 1724485  California  2016-03-21   3.552174        6  0.034208      39
# 1724489  California  2016-03-22   4.226087       18  0.026292      35
#
#          SO2 Mean  SO2 AQI   CO Mean  CO AQI   AQI
# 3516     0.636364      3.0  0.556522    22.0  25.0
# 3520     1.000000      3.0  0.578261     9.0  28.0
# 3524     2.454545      6.0  1.313043     9.0  38.0
# 3528     1.541667      6.0  1.187500    22.0  42.0
# 3532     1.681818      6.0  1.136364    23.0  36.0
# ...           ...      ...       ...     ...   ...
# 1724161  0.900000      1.0  0.339130     5.0  36.0
# 1724477  0.372727      0.0  0.400000     6.0  31.0
# 1724481  0.359091      0.0  0.391304     5.0  30.0
# 1724485  0.390909      0.0  0.395652     5.0  39.0
# 1724489  0.636364      1.0  0.369565     5.0  35.0
#
# [5965 rows x 11 columns]

# %%
def AQI_Range(x):
  if x<=50:
    return "Good"
  elif x>50 and x<=100:return "Moderate"
  elif x>100 and x<=200:return "Poor"
  elif x>200 and x<=300:return "Unhealthy"
  elif x>300 and x<=400:return "Very unhealthy"
  elif x>400:return "Hazardous"
df1['AQI Range'] = df1['AQI'] .apply(AQI_Range)
df1.head()
# Out:
#            State  Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  SO2 Mean  \
# 3516  California  2000-01-01  14.782609       25  0.015542      25  0.636364
# 3520  California  2000-01-02  16.043478       28  0.015292      27  1.000000
# 3524  California  2000-01-03  25.521739       38  0.005625      12  2.454545
# 3528  California  2000-01-04  26.041667       42  0.006083       9  1.541667
# 3532  California  2000-01-05  23.772727       36  0.010500      19  1.681818
#
#       SO2 AQI   CO Mean  CO AQI   AQI AQI Range
# 3516      3.0  0.556522    22.0  25.0      Good
# 3520      3.0  0.578261     9.0  28.0      Good
# 3524      6.0  1.313043     9.0  38.0      Good
# 3528      6.0  1.187500    22.0  42.0      Good
# 3532      6.0  1.136364    23.0  36.0      Good

# %%
x=df1[['NO2 AQI','O3 AQI','SO2 AQI','CO AQI']]
y=df1[['AQI']]
x.head()
# Out:
#       NO2 AQI  O3 AQI  SO2 AQI  CO AQI
# 3516       25      25      3.0    22.0
# 3520       28      27      3.0     9.0
# 3524       38      12      6.0     9.0
# 3528       42       9      6.0    22.0
# 3532       36      19      6.0    23.0

# %%
y.head()
# Out:
#        AQI
# 3516  25.0
# 3520  28.0
# 3524  38.0
# 3528  42.0
# 3532  36.0

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x, y, test_size=0.2, random_state=70)
print(X_train.shape, X_test. shape,Y_train. shape, Y_test.shape)
#splitting the data into training and testing data
# Out:
# (4772, 4) (1193, 4) (4772, 1) (1193, 1)

# %% [markdown]
# # linear regression

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
train_pred=model.predict(X_train)
test_pred=model.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train, train_pred)))
RMSE_test =(np.sqrt(metrics.mean_squared_error(Y_test, test_pred))) 
print("RMSE TrainingData=", str(RMSE_train))
print("RMSE TestData= ", str(RMSE_test))
print('-'*50)
print('RSquared value on train: ',model.score (X_train, Y_train)) 
print('RSquared value on test:',model.score (X_test, Y_test))
# Out:
# RMSE TrainingData= 4.833616634994241
# RMSE TestData=  5.0382941283093885
# --------------------------------------------------
# RSquared value on train:  0.8224451894977709
# RSquared value on test: 0.7782356412193391

# %% [markdown]
# # logistic Regression

# %%
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
train_pred=model.predict(X_train)
test_pred=model.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train, train_pred)))
RMSE_test =(np.sqrt(metrics.mean_squared_error(Y_test, test_pred))) 
print("RMSE TrainingData=", str(RMSE_train))
print("RMSE TestData= ", str(RMSE_test))
print('-'*50)
print('RSquared value on train: ',model.score (X_train, Y_train)) 
print('RSquared value on test:',model.score (X_test, Y_test))
# Out:
# RMSE TrainingData= 11.434679094827123
# RMSE TestData=  11.542987914384117
# --------------------------------------------------
# RSquared value on train:  0.10435875943000839
# RSquared value on test: 0.08633696563285834

# %% [markdown]
# # Decision Tree Regressor

# %%
DT=DecisionTreeRegressor()
DT.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
train_pred=DT.predict(X_train) 
test_pred=DT.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train, train_pred))) 
RMSE_test =(np.sqrt(metrics.mean_squared_error(Y_test, test_pred))) 
print("RMSE TrainingData=", str(RMSE_train)) 
print("RMSE TestData=",str(RMSE_test))
print('-'*50)
print('RSquared value on train:',DT.score (X_train, Y_train)) 
print('RSquared value on test:',DT.score (X_test, Y_test))
# Out:
# RMSE TrainingData= 0.0
# RMSE TestData= 2.4653508342545822
# --------------------------------------------------
# RSquared value on train: 1.0
# RSquared value on test: 0.946901509406588

# %%
Y_train.head()
print(train_pred)
# Out:
# [25. 29. 34. ... 22. 49. 24.]

# %%
Y_train
# Out:
#           AQI
# 1212272  25.0
# 872050   29.0
# 871246   34.0
# 636527   34.0
# 96502    48.0
# ...       ...
# 1476396  26.0
# 279289   30.0
# 980309   22.0
# 1476616  49.0
# 1082956  24.0
#
# [4772 rows x 1 columns]

# %% [markdown]
# # Random Forest Regressor

# %%
RF=RandomForestRegressor()
RF.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
train_pred=RF.predict(X_train)
test_pred=RF.predict(X_test)

# %%
RMSE_train=(np.sqrt(metrics.mean_squared_error(Y_train, train_pred)))
RMSE_test= (np.sqrt(metrics.mean_squared_error(Y_test, test_pred)))
print("RMSE TrainingData=", str(RMSE_train))
print("RMSE TestData=", str(RMSE_test))
print('-'*50)
print('RSquared value on train: ',RF.score (X_train, Y_train))
print('RSquared value on test:', RF.score (X_test, Y_test))
# Out:
# RMSE TrainingData= 0.336426539424538
# RMSE TestData= 2.4164509350579273
# --------------------------------------------------
# RSquared value on train:  0.999139861207913
# RSquared value on test: 0.9489870220093083

# %% [markdown]
# # ARIMA

# %%
new=['Date Local','AQI']
df2=df1[new]
df2
# Out:
#          Date Local   AQI
# 3516     2000-01-01  25.0
# 3520     2000-01-02  28.0
# 3524     2000-01-03  38.0
# 3528     2000-01-04  42.0
# 3532     2000-01-05  36.0
# ...             ...   ...
# 1724161  2016-04-30  36.0
# 1724477  2016-03-19  31.0
# 1724481  2016-03-20  30.0
# 1724485  2016-03-21  39.0
# 1724489  2016-03-22  35.0
#
# [5965 rows x 2 columns]

# %%
df3=df2.set_index('Date Local')
df3=df3[["AQI"]]
df3
# Out:
#              AQI
# Date Local
# 2000-01-01  25.0
# 2000-01-02  28.0
# 2000-01-03  38.0
# 2000-01-04  42.0
# 2000-01-05  36.0
# ...          ...
# 2016-04-30  36.0
# 2016-03-19  31.0
# 2016-03-20  30.0
# 2016-03-21  39.0
# 2016-03-22  35.0
#
# [5965 rows x 1 columns]

# %%
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm

# %%
from statsmodels.tsa.stattools import adfuller
stat_test = adfuller(df3['AQI'])
print('The test statistic for AQI is {} and p-value is {}'.format(stat_test[0], stat_test[1]))
# Out:
# The test statistic for AQI is -7.178090091476675 and p-value is 2.694205052344708e-10

# %%
sm.graphics.tsa.plot_acf(df3['AQI'], lags=35);

# %%
sm.graphics.tsa.plot_pacf(df3['AQI'], lags=35);

# %%
train_len = int(len(df3['AQI']) * 0.8)
df_train = df3[:train_len]
df_test = df3['AQI'][train_len:]
start = len(df_train)
end = len(df_train) + len(df_test) - 1

# %%
ma_model = ARIMA(df_train, order=(0, 0, 5))
ma_result = ma_model.fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
ma_pred = ma_result.predict(start, end)
rmse_ma = np.sqrt(mean_squared_error(df_test, ma_pred))
print("rmse:",rmse_ma)
# Out:
# rmse: 8.126675212582144
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
ma_pred.index = df_test.index
plt.plot(df_train.index, df_train, label='Train')
plt.plot(df_test.index, df_test, label='Test')
plt.plot(ma_pred.index , ma_pred, label='predictions')
print('moving average prediction of ')
    
plt.legend()
plt.xlabel('Date')
plt
# Out:
# moving average prediction of
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
ar_model = ARIMA(df_train, order=(5, 0, 0))
ar_result = ar_model.fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
ar_pred = ar_result.predict(start, end)
rmse_ar = np.sqrt(mean_squared_error(df_test, ar_pred))
print("rmse:",rmse_ar)
# Out:
# rmse: 8.129518650153335
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
arima_model = ARIMA(df_train, order=(5, 1, 8))
arima_result = arima_model.fit()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.9/dist-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
arima_pred = arima_result.predict(start, end)
rmse_arima = np.sqrt(mean_squared_error(df_test, arima_pred))
print("rmse:",rmse_arima)
# Out:
# rmse: 8.512519269081547
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
